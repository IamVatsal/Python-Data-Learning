# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# 1D Array
arr1 = np.array([1, 2, 3, 4, 5])
print("1D Array:", arr1)

# 2D Array
arr2 = np.array([[1, 2], [3, 4]])
print("2D Array:\n", arr2)

# Range of Numbers
arr3 = np.arange(0,10,2) # 0 to 10 step 2
print("Range Array:", arr3)

# Evenly Spaced Numbers
arr4 = np.linspace(0,1,5) # 5 numbers from 0 to 1
print("Linespace Array:", arr4)
# Out:
# 1D Array: [1 2 3 4 5]
# 2D Array:
#  [[1 2]
#  [3 4]]
# Range Array: [0 2 4 6 8]
# Linespace Array: [0.   0.25 0.5  0.75 1.  ]

# %%
print("Shape of arr2:", arr2.shape)
print("Dimensions:", arr2.ndim)
print("Data type:", arr2.dtype)
# Out:
# Shape of arr2: (2, 2)
# Dimensions: 2
# Data type: int64

# %%
# Random integers
rand_ints = np.random.randint(0,10,(3,3))
print("Random integers:\n", rand_ints)

# Random floats
rand_floats = np.random.rand(3,3)
print("Random floats:\n", rand_floats)
# Out:
# Random integers:
#  [[7 1 6]
#  [8 9 8]
#  [4 8 7]]
# Random floats:
#  [[0.66070562 0.39543288 0.39992528]
#  [0.88497994 0.00197685 0.37628982]
#  [0.78706833 0.97479832 0.93747493]]

# %%
# Plot a 1D array
plt.plot(arr1)
plt.title("line Plot of arr1")
plt.show()

# Show 2D random floats as heatmap
plt.imshow(rand_floats, cmap='viridis')
plt.colorbar(label='Value')
plt.title("Heatmap Of Random Floats")
plt.show()
