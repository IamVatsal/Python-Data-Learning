# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
arr1 = np.random.randint(0,15,(3,3))
print("arr1:\n", arr1)

arr2 = np.random.rand(3,3)
print("arr2:\n", arr2)
# Out:
# arr1:
#  [[ 9 12 10]
#  [11  9  6]
#  [10 10  8]]
# arr2:
#  [[0.20855349 0.17534657 0.39338775]
#  [0.93978423 0.04592621 0.46071277]
#  [0.59916734 0.43172515 0.75664569]]

# %%
# Sum
sum1 = np.sum(arr1)
print("\nSum of arr1: ", sum1)
print("Sum of arr1: ", arr1.sum())

sum2 = np.sum(arr2)
print("Sum of arr2: ", sum2)
print("Sum of arr2: ", arr2.sum())

sum_of_both_arr = arr1 + arr2
print("\nSum of arr1 + arr2:\n", sum_of_both_arr)
# Out:
# Sum of arr1:  85
# Sum of arr1:  85
# Sum of arr2:  4.011249198493345
# Sum of arr2:  4.011249198493345
#
# Sum of arr1 + arr2:
#  [[ 9.20855349 12.17534657 10.39338775]
#  [11.93978423  9.04592621  6.46071277]
#  [10.59916734 10.43172515  8.75664569]]

# %%
# Mean
mean1 = np.mean(arr1)
print("\nMean of arr1: ", mean1)
print("Mean of arr1: ", arr1.mean())

mean2 = np.mean(arr2)
print("Mean of arr2: ", mean2)
print("Mean of arr2: ", arr2.mean())
# Out:
# Mean of arr1:  9.444444444444445
# Mean of arr1:  9.444444444444445
# Mean of arr2:  0.4456943553881494
# Mean of arr2:  0.4456943553881494

# %%
# Transpose
arr1_transpose = np.transpose(arr1)
print("\nTranspose of arr1:\n", arr1_transpose)
print("\nTranspose of arr1:\n", arr1.transpose())
print("\nTranspose of arr1:\n", arr1.T) # just returns with changed axes


arr2_transpose = np.transpose(arr2)
print("\nTranspose of arr2:\n", arr2_transpose)
print("\nTranspose of arr2:\n", arr2.transpose())
print("Transpose of arr2:\n", arr2.T) # just returns with changed axes
# Out:
# Transpose of arr1:
#  [[ 9 11 10]
#  [12  9 10]
#  [10  6  8]]
#
# Transpose of arr1:
#  [[ 9 11 10]
#  [12  9 10]
#  [10  6  8]]
#
# Transpose of arr1:
#  [[ 9 11 10]
#  [12  9 10]
#  [10  6  8]]
#
# Transpose of arr2:
#  [[0.20855349 0.93978423 0.59916734]
#  [0.17534657 0.04592621 0.43172515]
#  [0.39338775 0.46071277 0.75664569]]
#
# Transpose of arr2:
#  [[0.20855349 0.93978423 0.59916734]
#  [0.17534657 0.04592621 0.43172515]
#  [0.39338775 0.46071277 0.75664569]]
# Transpose of arr2:
#  [[0.20855349 0.93978423 0.59916734]
#  [0.17534657 0.04592621 0.43172515]
#  [0.39338775 0.46071277 0.75664569]]

# %%
plt.imshow(arr1, cmap='viridis')
plt.title("Num Array")
plt.colorbar(label='Value')
plt.show()


plt.imshow(arr2, cmap='viridis')
plt.title("Float Array")
plt.colorbar(label='Value')
plt.show()
